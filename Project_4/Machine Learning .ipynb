# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np
from sklearn import datasets
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import mean_absolute_error
df = pd.read_csv("data_compressed.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\coopk\OneDrive\Desktop\Untitled5.ipynb Cell 1 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/coopk/OneDrive/Desktop/Untitled5.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a> from sklearn.metrics import silhouette_score
#      <a href='vscode-notebook-cell:/c%3A/Users/coopk/OneDrive/Desktop/Untitled5.ipynb#W0sZmlsZQ%3D%3D?line=11'>12</a> from sklearn.metrics import mean_absolute_error
# ---> <a href='vscode-notebook-cell:/c%3A/Users/coopk/OneDrive/Desktop/Untitled5.ipynb#W0sZmlsZQ%3D%3D?line=12'>13</a> from sklearn.esemble import RandomForestRegressor
#      <a href='vscode-notebook-cell:/c%3A/Users/coopk/OneDrive/Desktop/Untitled5.ipynb#W0sZmlsZQ%3D%3D?line=13'>14</a> df = pd.read_csv("data_compressed.csv")
#
# ModuleNotFoundError: No module named 'sklearn.esemble'

# %%
df
# Out:
#        housing_cost    food_cost  transportation_cost  healthcare_cost  \
# 0        8505.72876   3454.91712          10829.16876       5737.47984
# 1       12067.50240   5091.70788          11588.19288       8659.55640
# 2       12067.50240   7460.20308          12361.77720      11581.63260
# 3       15257.15040   9952.23924          13452.18600      14503.70760
# 4       15257.15040  12182.21400          13744.59840      17425.78560
# ...             ...          ...                  ...              ...
# 31415    8316.00000   6010.65672          14790.36240      14466.55920
# 31416   10956.00000   7480.86696          15611.58600      18086.24160
# 31417   10956.00000   9474.35748          16163.90280      21705.92280
# 31418   13632.00000  11567.46972          17118.38400      25325.60400
# 31419   13632.00000  14155.81080          17184.34920      28945.28640
#
#        other_necessities_cost  childcare_cost        taxes   total_cost  \
# ...

# %%
#Seperate into Train and Test DataFrames

df = df.sample(frac=1, random_state=2)
train_df = df[:25000]
train_df = train_df.reset_index(drop=True)
test_df = df[25000:]
test_df = test_df.reset_index(drop=True)

# %%
train_df
# Out:
#        housing_cost    food_cost  transportation_cost  healthcare_cost  \
# 0        8203.75632   5858.48772          12332.94960       9746.69976
# 1        5664.00000   3039.91200          11556.09672       5302.79004
# 2       10452.00000  10359.47388          15339.26640      24921.84960
# 3        9672.00000   8756.77512          12316.96920      12859.02360
# 4        6516.00000   5573.17200          13611.82920       9901.37988
# ...             ...          ...                  ...              ...
# 24995    8697.91188   8874.71412          15134.80560      16420.99080
# 24996   16632.00000   3963.29772           8806.32720       6328.54032
# 24997    9876.00000  10139.83884          14389.33920      24000.32760
# 24998    6036.00000   3154.03824          11137.67868       5898.69000
# 24999   14004.00000  12548.04600          14912.44320      13108.06320
#
#        other_necessities_cost  childcare_cost        taxes  total_cost  \
# ...

# %%
test_df
# Out:
#       housing_cost    food_cost  transportation_cost  healthcare_cost  \
# 0         9240.000   8424.98220          14642.58720      19499.00640
# 1        11424.000   9534.32148          14107.73280      16239.61560
# 2         7944.000   4158.99204          10801.32792      10306.33884
# 3         9552.000   6048.81336          13551.29040      10723.64064
# 4        14796.000  14738.16960          16137.38400      16647.89640
# ...            ...          ...                  ...              ...
# 6415     24466.542  15008.42520          15165.24600      16190.32080
# 6416      6552.000   2873.90976          11348.61480       7318.79004
# 6417      8652.000   7855.32060          14276.24160      18241.63440
# 6418      8196.000   6276.95136          14592.49080       8706.56028
# 6419      6036.000   3371.91576          11729.10060       6498.69000
#
#       other_necessities_cost  childcare_cost        taxes   total_cost  \
# ...

# %%
y_train = train_df['housing_cost'].to_numpy()
y_test = test_df['housing_cost'].to_numpy()

y_train.shape, y_test.shape
# Out:
# ((25000,), (6420,))

# %%
# Get error of baseline model


average_housing_cost = train_df['housing_cost'].mean()
baseline_model_test_predictions = [average_housing_cost] * len(test_df)

mean_absolute_error(baseline_model_test_predictions, y_test)
# Out:
# 2838.302903254783

# %%
train_df[['housing_cost' , 'median_family_income', 'food_cost']].corr()
# Out:
#                       housing_cost  median_family_income  food_cost
# housing_cost              1.000000              0.583345   0.578886
# median_family_income      0.583345              1.000000   0.128180
# food_cost                 0.578886              0.128180   1.000000

# %%
x_train_3 = train_df[['housing_cost' , 'median_family_income', 'food_cost']].to_numpy()

x_train_3.shape
# Out:
# (25000, 3)

# %%
x_test_3 = test_df[['housing_cost' , 'median_family_income', 'food_cost']].to_numpy()

x_test_3.shape
# Out:
# (6420, 3)

# %%
forest_base = RandomForestRegressor(n_estimators=50, max_depth=5).fit(X_train_3, y_train)
forest_base_test_predictions = forest_base.predict(X_test_3)
mean_absolute_error(y_test, forest_base_test_predictions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\coopk\OneDrive\Desktop\Untitled5.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/coopk/OneDrive/Desktop/Untitled5.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> forest_base = RandomForestRegressor(n_estimators=50, max_depth=5).fit(X_train_3, y_train)
#       <a href='vscode-notebook-cell:/c%3A/Users/coopk/OneDrive/Desktop/Untitled5.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a> forest_base_test_predictions = forest_base.predict(X_test_3)
#       <a href='vscode-notebook-cell:/c%3A/Users/coopk/OneDrive/Desktop/Untitled5.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a> mean_absolute_error(y_test, forest_base_test_predictions)
#
# NameError: name 'RandomForestRegressor' is not defined
